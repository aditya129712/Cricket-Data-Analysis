# %% [markdown]
# ### Cricket Data Analysis

# %%
#Import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Import the Dataset

# %%
##Import the Dataset
dataset1 =  pd.read_csv('Batsman_data.csv')
dataset1.head()
# Out:
#   BAT1 RUNS BF SR `4S` `6S`    OPPOSITION   GROUND `START_DATE`    MATCH_ID  \
# 0  DNB    -  -  -    -    -       v India   Nagpur    18-Dec-09  ODI # 2933
# 1  DNB    -  -  -    -    -       v India  Kolkata    24-Dec-09  ODI # 2935
# 2  DNB    -  -  -    -    -       v India    Delhi    27-Dec-09  ODI # 2936
# 3  DNB    -  -  -    -    -  v Bangladesh    Dhaka    04-Jan-10  ODI # 2937
# 4  DNB    -  -  -    -    -       v India    Dhaka    05-Jan-10  ODI # 2938
#
#          BATSMAN  PLAYER_ID
# 0  Oshane Thomas      49619
# 1  Oshane Thomas      49619
# 2  Oshane Thomas      49619
# 3  Oshane Thomas      49619
# 4  Oshane Thomas      49619

# %%
dataset2 =pd.read_csv('Bowler_data.csv')
dataset2.head()
# Out:
#   OVERS MDNS RUNS WKTS  ECON   AVE  SR    OPPOSITION   GROUND `START_DATE`  \
# 0     8    0   57    0  7.12     -   -       v India   Nagpur    18-Dec-09
# 1    10    0   55    2   5.5  27.5  30       v India  Kolkata    24-Dec-09
# 2     -    -    -    -     -     -   -       v India    Delhi    27-Dec-09
# 3     9    1   63    2     7  31.5  27  v Bangladesh    Dhaka    04-Jan-10
# 4     8    1   48    0     6     -   -       v India    Dhaka    05-Jan-10
#
#      MATCH_ID          BOWLER  PLAYER_ID
# 0  ODI # 2933  Suranga Lakmal      49619
# 1  ODI # 2935  Suranga Lakmal      49619
# 2  ODI # 2936  Suranga Lakmal      49619
# 3  ODI # 2937  Suranga Lakmal      49619
# 4  ODI # 2938  Suranga Lakmal      49619

# %%
dataset3 = pd.read_csv('Match_Result_data.csv')
dataset3.head()
# Out:
#   RESULT    MARGIN  TOSS  BAT   OPPOSITION     GROUND `START_DATE`  \
# 0    won   85 runs  lost  1st      v India    Kolkata    03-Jan-13
# 1   lost   85 runs   won  2nd   v Pakistan    Kolkata    03-Jan-13
# 2   lost   10 runs  lost  2nd      v India      Delhi    06-Jan-13
# 3    won   10 runs   won  1st   v Pakistan      Delhi    06-Jan-13
# 4   lost  107 runs  lost  2nd  v Australia  Melbourne    11-Jan-13
#
#      MATCH_ID   COUNTRY  COUNTRY_ID
# 0  ODI # 3315  Pakistan           7
# 1  ODI # 3315     India           6
# 2  ODI # 3316  Pakistan           7
# 3  ODI # 3316     India           6
# 4  ODI # 3317  SriLanka           8

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11149 entries, 0 to 11148
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   BAT1          11149 non-null  object
#  1   RUNS          11149 non-null  object
#  2   BF            11149 non-null  object
#  3   SR            11149 non-null  object
#  4   `4S`          11149 non-null  object
#  5   `6S`          11149 non-null  object
#  6   OPPOSITION    11149 non-null  object
#  7   GROUND        11149 non-null  object
#  8   `START_DATE`  11149 non-null  object
#  9   MATCH_ID      11149 non-null  object
#  10  BATSMAN       11149 non-null  object
#  11  PLAYER_ID     11149 non-null  int64
# dtypes: int64(1), object(11)
# memory usage: 1.0+ MB

# %%
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11118 entries, 0 to 11117
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OVERS         11118 non-null  object
#  1   MDNS          11118 non-null  object
#  2   RUNS          11118 non-null  object
#  3   WKTS          11118 non-null  object
#  4   ECON          11118 non-null  object
#  5   AVE           11118 non-null  object
#  6   SR            11118 non-null  object
#  7   OPPOSITION    11118 non-null  object
#  8   GROUND        11118 non-null  object
#  9   `START_DATE`  11118 non-null  object
#  10  MATCH_ID      11118 non-null  object
#  11  BOWLER        11118 non-null  object
#  12  PLAYER_ID     11118 non-null  int64
# dtypes: int64(1), object(12)
# memory usage: 1.1+ MB

# %%
dataset3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1322 entries, 0 to 1321
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   RESULT        1322 non-null   object
#  1   MARGIN        1322 non-null   object
#  2   TOSS          1322 non-null   object
#  3   BAT           1322 non-null   object
#  4   OPPOSITION    1322 non-null   object
#  5   GROUND        1322 non-null   object
#  6   `START_DATE`  1322 non-null   object
#  7   MATCH_ID      1322 non-null   object
#  8   COUNTRY       1322 non-null   object
#  9   COUNTRY_ID    1322 non-null   int64
# dtypes: int64(1), object(9)
# memory usage: 103.4+ KB

# %%
dataset1.isna().sum()
# Out:
# BAT1            0
# RUNS            0
# BF              0
# SR              0
# `4S`            0
# `6S`            0
# OPPOSITION      0
# GROUND          0
# `START_DATE`    0
# MATCH_ID        0
# BATSMAN         0
# PLAYER_ID       0
# dtype: int64

# %%
dataset1
# Out:
#        BAT1 RUNS  BF    SR `4S` `6S`    OPPOSITION     GROUND `START_DATE`  \
# 0       DNB    -   -     -    -    -       v India     Nagpur    18-Dec-09
# 1       DNB    -   -     -    -    -       v India    Kolkata    24-Dec-09
# 2       DNB    -   -     -    -    -       v India      Delhi    27-Dec-09
# 3       DNB    -   -     -    -    -  v Bangladesh      Dhaka    04-Jan-10
# 4       DNB    -   -     -    -    -       v India      Dhaka    05-Jan-10
# ...     ...  ...  ..   ...  ...  ...           ...        ...          ...
# 11144    46   46  61  75.4    6    1     v Ireland   Dehradun    28-Feb-19
# 11145     3    3   6    50    0    0     v Ireland   Dehradun    02-Mar-19
# 11146     1    1   8  12.5    0    0     v Ireland   Dehradun    08-Mar-19
# 11147   DNB    -   -     -    -    -    v Scotland  Edinburgh    10-May-19
# 11148  TDNB    -   -     -    -    -     v Ireland    Belfast    19-May-19
#
#          MATCH_ID         BATSMAN  PLAYER_ID
# ...

# %%
dataset1['RUNS'].isnull().sum()
# Out:
# 0

# %%
dataset1['RUNS'] = dataset1['RUNS'].replace('-','0')

# %%
dataset1
# Out:
#        BAT1 RUNS  BF    SR `4S` `6S`    OPPOSITION     GROUND `START_DATE`  \
# 0       DNB    0   -     -    -    -       v India     Nagpur    18-Dec-09
# 1       DNB    0   -     -    -    -       v India    Kolkata    24-Dec-09
# 2       DNB    0   -     -    -    -       v India      Delhi    27-Dec-09
# 3       DNB    0   -     -    -    -  v Bangladesh      Dhaka    04-Jan-10
# 4       DNB    0   -     -    -    -       v India      Dhaka    05-Jan-10
# ...     ...  ...  ..   ...  ...  ...           ...        ...          ...
# 11144    46   46  61  75.4    6    1     v Ireland   Dehradun    28-Feb-19
# 11145     3    3   6    50    0    0     v Ireland   Dehradun    02-Mar-19
# 11146     1    1   8  12.5    0    0     v Ireland   Dehradun    08-Mar-19
# 11147   DNB    0   -     -    -    -    v Scotland  Edinburgh    10-May-19
# 11148  TDNB    0   -     -    -    -     v Ireland    Belfast    19-May-19
#
#          MATCH_ID         BATSMAN  PLAYER_ID
# ...

# %%
dataset1['BAT1']=dataset1['BAT1'].str.split('*').str[0]
dataset1
# Out:
#        BAT1 RUNS  BF    SR `4S` `6S`    OPPOSITION     GROUND `START_DATE`  \
# 0       DNB    0   -     -    -    -       v India     Nagpur    18-Dec-09
# 1       DNB    0   -     -    -    -       v India    Kolkata    24-Dec-09
# 2       DNB    0   -     -    -    -       v India      Delhi    27-Dec-09
# 3       DNB    0   -     -    -    -  v Bangladesh      Dhaka    04-Jan-10
# 4       DNB    0   -     -    -    -       v India      Dhaka    05-Jan-10
# ...     ...  ...  ..   ...  ...  ...           ...        ...          ...
# 11144    46   46  61  75.4    6    1     v Ireland   Dehradun    28-Feb-19
# 11145     3    3   6    50    0    0     v Ireland   Dehradun    02-Mar-19
# 11146     1    1   8  12.5    0    0     v Ireland   Dehradun    08-Mar-19
# 11147   DNB    0   -     -    -    -    v Scotland  Edinburgh    10-May-19
# 11148  TDNB    0   -     -    -    -     v Ireland    Belfast    19-May-19
#
#          MATCH_ID         BATSMAN  PLAYER_ID
# ...

# %%
dataset1['BF'] = dataset1['BF'].replace('-','0')

# %%
dataset1
# Out:
#        BAT1 RUNS  BF    SR `4S` `6S`    OPPOSITION     GROUND `START_DATE`  \
# 0       DNB    0   0     -    -    -       v India     Nagpur    18-Dec-09
# 1       DNB    0   0     -    -    -       v India    Kolkata    24-Dec-09
# 2       DNB    0   0     -    -    -       v India      Delhi    27-Dec-09
# 3       DNB    0   0     -    -    -  v Bangladesh      Dhaka    04-Jan-10
# 4       DNB    0   0     -    -    -       v India      Dhaka    05-Jan-10
# ...     ...  ...  ..   ...  ...  ...           ...        ...          ...
# 11144    46   46  61  75.4    6    1     v Ireland   Dehradun    28-Feb-19
# 11145     3    3   6    50    0    0     v Ireland   Dehradun    02-Mar-19
# 11146     1    1   8  12.5    0    0     v Ireland   Dehradun    08-Mar-19
# 11147   DNB    0   0     -    -    -    v Scotland  Edinburgh    10-May-19
# 11148  TDNB    0   0     -    -    -     v Ireland    Belfast    19-May-19
#
#          MATCH_ID         BATSMAN  PLAYER_ID
# ...

# %%
dataset1['SR'] = dataset1['SR'].replace('-','0')

# %%
dataset1
# Out:
#        BAT1 RUNS  BF    SR `4S` `6S`    OPPOSITION     GROUND `START_DATE`  \
# 0       DNB    0   0     0    -    -       v India     Nagpur    18-Dec-09
# 1       DNB    0   0     0    -    -       v India    Kolkata    24-Dec-09
# 2       DNB    0   0     0    -    -       v India      Delhi    27-Dec-09
# 3       DNB    0   0     0    -    -  v Bangladesh      Dhaka    04-Jan-10
# 4       DNB    0   0     0    -    -       v India      Dhaka    05-Jan-10
# ...     ...  ...  ..   ...  ...  ...           ...        ...          ...
# 11144    46   46  61  75.4    6    1     v Ireland   Dehradun    28-Feb-19
# 11145     3    3   6    50    0    0     v Ireland   Dehradun    02-Mar-19
# 11146     1    1   8  12.5    0    0     v Ireland   Dehradun    08-Mar-19
# 11147   DNB    0   0     0    -    -    v Scotland  Edinburgh    10-May-19
# 11148  TDNB    0   0     0    -    -     v Ireland    Belfast    19-May-19
#
#          MATCH_ID         BATSMAN  PLAYER_ID
# ...

# %%
dataset1['`4S`'] = dataset1['`4S`'].replace('-','0')

# %%
dataset1
# Out:
#        BAT1 RUNS  BF    SR `4S` `6S`    OPPOSITION     GROUND `START_DATE`  \
# 0       DNB    0   0     0    0    -       v India     Nagpur    18-Dec-09
# 1       DNB    0   0     0    0    -       v India    Kolkata    24-Dec-09
# 2       DNB    0   0     0    0    -       v India      Delhi    27-Dec-09
# 3       DNB    0   0     0    0    -  v Bangladesh      Dhaka    04-Jan-10
# 4       DNB    0   0     0    0    -       v India      Dhaka    05-Jan-10
# ...     ...  ...  ..   ...  ...  ...           ...        ...          ...
# 11144    46   46  61  75.4    6    1     v Ireland   Dehradun    28-Feb-19
# 11145     3    3   6    50    0    0     v Ireland   Dehradun    02-Mar-19
# 11146     1    1   8  12.5    0    0     v Ireland   Dehradun    08-Mar-19
# 11147   DNB    0   0     0    0    -    v Scotland  Edinburgh    10-May-19
# 11148  TDNB    0   0     0    0    -     v Ireland    Belfast    19-May-19
#
#          MATCH_ID         BATSMAN  PLAYER_ID
# ...

# %%
dataset1['`6S`'] = dataset1['`6S`'].replace('-','0')

# %%
dataset1
# Out:
#        BAT1 RUNS  BF    SR `4S` `6S`    OPPOSITION     GROUND `START_DATE`  \
# 0       DNB    0   0     0    0    0       v India     Nagpur    18-Dec-09
# 1       DNB    0   0     0    0    0       v India    Kolkata    24-Dec-09
# 2       DNB    0   0     0    0    0       v India      Delhi    27-Dec-09
# 3       DNB    0   0     0    0    0  v Bangladesh      Dhaka    04-Jan-10
# 4       DNB    0   0     0    0    0       v India      Dhaka    05-Jan-10
# ...     ...  ...  ..   ...  ...  ...           ...        ...          ...
# 11144    46   46  61  75.4    6    1     v Ireland   Dehradun    28-Feb-19
# 11145     3    3   6    50    0    0     v Ireland   Dehradun    02-Mar-19
# 11146     1    1   8  12.5    0    0     v Ireland   Dehradun    08-Mar-19
# 11147   DNB    0   0     0    0    0    v Scotland  Edinburgh    10-May-19
# 11148  TDNB    0   0     0    0    0     v Ireland    Belfast    19-May-19
#
#          MATCH_ID         BATSMAN  PLAYER_ID
# ...

# %%
new_opposition = dataset1['OPPOSITION'].str.split(' ').str[0]

# %%
new_opposition
# Out:
# 0        v
# 1        v
# 2        v
# 3        v
# 4        v
#         ..
# 11144    v
# 11145    v
# 11146    v
# 11147    v
# 11148    v
# Name: OPPOSITION, Length: 11149, dtype: object

# %%
dataset1['OPPOSITION']=dataset1['OPPOSITION'].str.split(' ').str[1]

# %%
dataset1
# Out:
#        BAT1 RUNS  BF    SR `4S` `6S`  OPPOSITION     GROUND `START_DATE`  \
# 0       DNB    0   0     0    0    0       India     Nagpur    18-Dec-09
# 1       DNB    0   0     0    0    0       India    Kolkata    24-Dec-09
# 2       DNB    0   0     0    0    0       India      Delhi    27-Dec-09
# 3       DNB    0   0     0    0    0  Bangladesh      Dhaka    04-Jan-10
# 4       DNB    0   0     0    0    0       India      Dhaka    05-Jan-10
# ...     ...  ...  ..   ...  ...  ...         ...        ...          ...
# 11144    46   46  61  75.4    6    1     Ireland   Dehradun    28-Feb-19
# 11145     3    3   6    50    0    0     Ireland   Dehradun    02-Mar-19
# 11146     1    1   8  12.5    0    0     Ireland   Dehradun    08-Mar-19
# 11147   DNB    0   0     0    0    0    Scotland  Edinburgh    10-May-19
# 11148  TDNB    0   0     0    0    0     Ireland    Belfast    19-May-19
#
#          MATCH_ID         BATSMAN  PLAYER_ID
# 0      ODI # 2933   Oshane Thomas      49619
# ...

# %%
dataset1['MATCH_ID'].unique()
# Out:
# array(['ODI # 2933', 'ODI # 2935', 'ODI # 2936', ..., 'ODI # 3720',
#        'ODI # 3722', 'ODI # 3573'], dtype=object)

# %%
dataset1['MATCH_ID']=dataset1['MATCH_ID'].str.split('ODI # ').str[1]

# %%
dataset1
# Out:
#        BAT1 RUNS  BF    SR `4S` `6S`  OPPOSITION     GROUND `START_DATE`  \
# 0       DNB    0   0     0    0    0       India     Nagpur    18-Dec-09
# 1       DNB    0   0     0    0    0       India    Kolkata    24-Dec-09
# 2       DNB    0   0     0    0    0       India      Delhi    27-Dec-09
# 3       DNB    0   0     0    0    0  Bangladesh      Dhaka    04-Jan-10
# 4       DNB    0   0     0    0    0       India      Dhaka    05-Jan-10
# ...     ...  ...  ..   ...  ...  ...         ...        ...          ...
# 11144    46   46  61  75.4    6    1     Ireland   Dehradun    28-Feb-19
# 11145     3    3   6    50    0    0     Ireland   Dehradun    02-Mar-19
# 11146     1    1   8  12.5    0    0     Ireland   Dehradun    08-Mar-19
# 11147   DNB    0   0     0    0    0    Scotland  Edinburgh    10-May-19
# 11148  TDNB    0   0     0    0    0     Ireland    Belfast    19-May-19
#
#       MATCH_ID         BATSMAN  PLAYER_ID
# 0         2933   Oshane Thomas      49619
# ...

# %%
dataset1['`START_DATE`']= pd.to_datetime(dataset1['`START_DATE`'])

# %%
dataset1
# Out:
#        BAT1 RUNS  BF    SR `4S` `6S`  OPPOSITION     GROUND `START_DATE`  \
# 0       DNB    0   0     0    0    0       India     Nagpur   2009-12-18
# 1       DNB    0   0     0    0    0       India    Kolkata   2009-12-24
# 2       DNB    0   0     0    0    0       India      Delhi   2009-12-27
# 3       DNB    0   0     0    0    0  Bangladesh      Dhaka   2010-01-04
# 4       DNB    0   0     0    0    0       India      Dhaka   2010-01-05
# ...     ...  ...  ..   ...  ...  ...         ...        ...          ...
# 11144    46   46  61  75.4    6    1     Ireland   Dehradun   2019-02-28
# 11145     3    3   6    50    0    0     Ireland   Dehradun   2019-03-02
# 11146     1    1   8  12.5    0    0     Ireland   Dehradun   2019-03-08
# 11147   DNB    0   0     0    0    0    Scotland  Edinburgh   2019-05-10
# 11148  TDNB    0   0     0    0    0     Ireland    Belfast   2019-05-19
#
#       MATCH_ID         BATSMAN  PLAYER_ID
# 0         2933   Oshane Thomas      49619
# ...

# %%
dataset2
# Out:
#       OVERS MDNS RUNS WKTS   ECON   AVE  SR    OPPOSITION       GROUND  \
# 0         8    0   57    0   7.12     -   -       v India       Nagpur
# 1        10    0   55    2    5.5  27.5  30       v India      Kolkata
# 2         -    -    -    -      -     -   -       v India        Delhi
# 3         9    1   63    2      7  31.5  27  v Bangladesh        Dhaka
# 4         8    1   48    0      6     -   -       v India        Dhaka
# ...     ...  ...  ...  ...    ...   ...  ..           ...          ...
# 11113     4    0   41    0  10.25     -   -       v India  Dubai (DSC)
# 11114   7.2    0   20    2   2.72    10  22     v Ireland     Dehradun
# 11115     -    -    -    -      -     -   -     v Ireland     Dehradun
# 11116     6    0   21    1    3.5    21  36     v Ireland     Dehradun
# 11117    10    0   72    3    7.2    24  20    v Scotland    Edinburgh
#
#       `START_DATE`    MATCH_ID          BOWLER  PLAYER_ID
# ...

# %%
dataset2['OVERS'] = dataset2['OVERS'].replace('-','0')

# %%
dataset2
# Out:
#       OVERS MDNS RUNS WKTS   ECON   AVE  SR    OPPOSITION       GROUND  \
# 0         8    0   57    0   7.12     -   -       v India       Nagpur
# 1        10    0   55    2    5.5  27.5  30       v India      Kolkata
# 2         0    -    -    -      -     -   -       v India        Delhi
# 3         9    1   63    2      7  31.5  27  v Bangladesh        Dhaka
# 4         8    1   48    0      6     -   -       v India        Dhaka
# ...     ...  ...  ...  ...    ...   ...  ..           ...          ...
# 11113     4    0   41    0  10.25     -   -       v India  Dubai (DSC)
# 11114   7.2    0   20    2   2.72    10  22     v Ireland     Dehradun
# 11115     0    -    -    -      -     -   -     v Ireland     Dehradun
# 11116     6    0   21    1    3.5    21  36     v Ireland     Dehradun
# 11117    10    0   72    3    7.2    24  20    v Scotland    Edinburgh
#
#       `START_DATE`    MATCH_ID          BOWLER  PLAYER_ID
# ...

# %%
dataset2['MDNS'] = dataset2['MDNS'].replace('-','0')

# %%
dataset2
# Out:
#       OVERS MDNS RUNS WKTS   ECON   AVE  SR    OPPOSITION       GROUND  \
# 0         8    0   57    0   7.12     -   -       v India       Nagpur
# 1        10    0   55    2    5.5  27.5  30       v India      Kolkata
# 2         0    0    -    -      -     -   -       v India        Delhi
# 3         9    1   63    2      7  31.5  27  v Bangladesh        Dhaka
# 4         8    1   48    0      6     -   -       v India        Dhaka
# ...     ...  ...  ...  ...    ...   ...  ..           ...          ...
# 11113     4    0   41    0  10.25     -   -       v India  Dubai (DSC)
# 11114   7.2    0   20    2   2.72    10  22     v Ireland     Dehradun
# 11115     0    0    -    -      -     -   -     v Ireland     Dehradun
# 11116     6    0   21    1    3.5    21  36     v Ireland     Dehradun
# 11117    10    0   72    3    7.2    24  20    v Scotland    Edinburgh
#
#       `START_DATE`    MATCH_ID          BOWLER  PLAYER_ID
# ...

# %%
dataset2['RUNS'] = dataset2['RUNS'].replace('-','0')

# %%
dataset2
# Out:
#       OVERS MDNS RUNS WKTS   ECON   AVE  SR    OPPOSITION       GROUND  \
# 0         8    0   57    0   7.12     -   -       v India       Nagpur
# 1        10    0   55    2    5.5  27.5  30       v India      Kolkata
# 2         0    0    0    -      -     -   -       v India        Delhi
# 3         9    1   63    2      7  31.5  27  v Bangladesh        Dhaka
# 4         8    1   48    0      6     -   -       v India        Dhaka
# ...     ...  ...  ...  ...    ...   ...  ..           ...          ...
# 11113     4    0   41    0  10.25     -   -       v India  Dubai (DSC)
# 11114   7.2    0   20    2   2.72    10  22     v Ireland     Dehradun
# 11115     0    0    0    -      -     -   -     v Ireland     Dehradun
# 11116     6    0   21    1    3.5    21  36     v Ireland     Dehradun
# 11117    10    0   72    3    7.2    24  20    v Scotland    Edinburgh
#
#       `START_DATE`    MATCH_ID          BOWLER  PLAYER_ID
# ...

# %%
dataset2['WKTS'] = dataset2['WKTS'].replace('-','0')
dataset2
# Out:
#       OVERS MDNS RUNS WKTS   ECON   AVE  SR    OPPOSITION       GROUND  \
# 0         8    0   57    0   7.12     -   -       v India       Nagpur
# 1        10    0   55    2    5.5  27.5  30       v India      Kolkata
# 2         0    0    0    0      -     -   -       v India        Delhi
# 3         9    1   63    2      7  31.5  27  v Bangladesh        Dhaka
# 4         8    1   48    0      6     -   -       v India        Dhaka
# ...     ...  ...  ...  ...    ...   ...  ..           ...          ...
# 11113     4    0   41    0  10.25     -   -       v India  Dubai (DSC)
# 11114   7.2    0   20    2   2.72    10  22     v Ireland     Dehradun
# 11115     0    0    0    0      -     -   -     v Ireland     Dehradun
# 11116     6    0   21    1    3.5    21  36     v Ireland     Dehradun
# 11117    10    0   72    3    7.2    24  20    v Scotland    Edinburgh
#
#       `START_DATE`    MATCH_ID          BOWLER  PLAYER_ID
# ...

# %%
dataset2['ECON'] = dataset2['ECON'].replace('-','0')
dataset2
# Out:
#       OVERS MDNS RUNS WKTS   ECON   AVE  SR    OPPOSITION       GROUND  \
# 0         8    0   57    0   7.12     -   -       v India       Nagpur
# 1        10    0   55    2    5.5  27.5  30       v India      Kolkata
# 2         0    0    0    0      0     -   -       v India        Delhi
# 3         9    1   63    2      7  31.5  27  v Bangladesh        Dhaka
# 4         8    1   48    0      6     -   -       v India        Dhaka
# ...     ...  ...  ...  ...    ...   ...  ..           ...          ...
# 11113     4    0   41    0  10.25     -   -       v India  Dubai (DSC)
# 11114   7.2    0   20    2   2.72    10  22     v Ireland     Dehradun
# 11115     0    0    0    0      0     -   -     v Ireland     Dehradun
# 11116     6    0   21    1    3.5    21  36     v Ireland     Dehradun
# 11117    10    0   72    3    7.2    24  20    v Scotland    Edinburgh
#
#       `START_DATE`    MATCH_ID          BOWLER  PLAYER_ID
# ...

# %%
dataset2['AVE']=dataset2['AVE'].replace('-','0')
dataset2
# Out:
#       OVERS MDNS RUNS WKTS   ECON   AVE  SR    OPPOSITION       GROUND  \
# 0         8    0   57    0   7.12     0   -       v India       Nagpur
# 1        10    0   55    2    5.5  27.5  30       v India      Kolkata
# 2         0    0    0    0      0     0   -       v India        Delhi
# 3         9    1   63    2      7  31.5  27  v Bangladesh        Dhaka
# 4         8    1   48    0      6     0   -       v India        Dhaka
# ...     ...  ...  ...  ...    ...   ...  ..           ...          ...
# 11113     4    0   41    0  10.25     0   -       v India  Dubai (DSC)
# 11114   7.2    0   20    2   2.72    10  22     v Ireland     Dehradun
# 11115     0    0    0    0      0     0   -     v Ireland     Dehradun
# 11116     6    0   21    1    3.5    21  36     v Ireland     Dehradun
# 11117    10    0   72    3    7.2    24  20    v Scotland    Edinburgh
#
#       `START_DATE`    MATCH_ID          BOWLER  PLAYER_ID
# ...

# %%
dataset2['SR']=dataset2['SR'].replace('-','0')
dataset2
# Out:
#       OVERS MDNS RUNS WKTS   ECON   AVE  SR    OPPOSITION       GROUND  \
# 0         8    0   57    0   7.12     0   0       v India       Nagpur
# 1        10    0   55    2    5.5  27.5  30       v India      Kolkata
# 2         0    0    0    0      0     0   0       v India        Delhi
# 3         9    1   63    2      7  31.5  27  v Bangladesh        Dhaka
# 4         8    1   48    0      6     0   0       v India        Dhaka
# ...     ...  ...  ...  ...    ...   ...  ..           ...          ...
# 11113     4    0   41    0  10.25     0   0       v India  Dubai (DSC)
# 11114   7.2    0   20    2   2.72    10  22     v Ireland     Dehradun
# 11115     0    0    0    0      0     0   0     v Ireland     Dehradun
# 11116     6    0   21    1    3.5    21  36     v Ireland     Dehradun
# 11117    10    0   72    3    7.2    24  20    v Scotland    Edinburgh
#
#       `START_DATE`    MATCH_ID          BOWLER  PLAYER_ID
# ...

# %%
dataset2['OPPOSITION']=dataset2['OPPOSITION'].str.split('v ').str[1]
dataset2
# Out:
#       OVERS MDNS RUNS WKTS   ECON   AVE  SR  OPPOSITION       GROUND  \
# 0         8    0   57    0   7.12     0   0       India       Nagpur
# 1        10    0   55    2    5.5  27.5  30       India      Kolkata
# 2         0    0    0    0      0     0   0       India        Delhi
# 3         9    1   63    2      7  31.5  27  Bangladesh        Dhaka
# 4         8    1   48    0      6     0   0       India        Dhaka
# ...     ...  ...  ...  ...    ...   ...  ..         ...          ...
# 11113     4    0   41    0  10.25     0   0       India  Dubai (DSC)
# 11114   7.2    0   20    2   2.72    10  22     Ireland     Dehradun
# 11115     0    0    0    0      0     0   0     Ireland     Dehradun
# 11116     6    0   21    1    3.5    21  36     Ireland     Dehradun
# 11117    10    0   72    3    7.2    24  20    Scotland    Edinburgh
#
#       `START_DATE`    MATCH_ID          BOWLER  PLAYER_ID
# 0        18-Dec-09  ODI # 2933  Suranga Lakmal      49619
# ...

# %%
dataset2['MATCH_ID']=dataset2['MATCH_ID'].str.split('ODI # ').str[1]

# %%
dataset2
# Out:
#       OVERS MDNS RUNS WKTS   ECON   AVE  SR  OPPOSITION       GROUND  \
# 0         8    0   57    0   7.12     0   0       India       Nagpur
# 1        10    0   55    2    5.5  27.5  30       India      Kolkata
# 2         0    0    0    0      0     0   0       India        Delhi
# 3         9    1   63    2      7  31.5  27  Bangladesh        Dhaka
# 4         8    1   48    0      6     0   0       India        Dhaka
# ...     ...  ...  ...  ...    ...   ...  ..         ...          ...
# 11113     4    0   41    0  10.25     0   0       India  Dubai (DSC)
# 11114   7.2    0   20    2   2.72    10  22     Ireland     Dehradun
# 11115     0    0    0    0      0     0   0     Ireland     Dehradun
# 11116     6    0   21    1    3.5    21  36     Ireland     Dehradun
# 11117    10    0   72    3    7.2    24  20    Scotland    Edinburgh
#
#       `START_DATE` MATCH_ID          BOWLER  PLAYER_ID
# 0        18-Dec-09     2933  Suranga Lakmal      49619
# ...

# %%
dataset2['`START_DATE`']=pd.to_datetime(dataset2['`START_DATE`'])

# %%
dataset2
# Out:
#       OVERS MDNS RUNS WKTS   ECON   AVE  SR  OPPOSITION       GROUND  \
# 0         8    0   57    0   7.12     0   0       India       Nagpur
# 1        10    0   55    2    5.5  27.5  30       India      Kolkata
# 2         0    0    0    0      0     0   0       India        Delhi
# 3         9    1   63    2      7  31.5  27  Bangladesh        Dhaka
# 4         8    1   48    0      6     0   0       India        Dhaka
# ...     ...  ...  ...  ...    ...   ...  ..         ...          ...
# 11113     4    0   41    0  10.25     0   0       India  Dubai (DSC)
# 11114   7.2    0   20    2   2.72    10  22     Ireland     Dehradun
# 11115     0    0    0    0      0     0   0     Ireland     Dehradun
# 11116     6    0   21    1    3.5    21  36     Ireland     Dehradun
# 11117    10    0   72    3    7.2    24  20    Scotland    Edinburgh
#
#       `START_DATE` MATCH_ID          BOWLER  PLAYER_ID
# 0       2009-12-18     2933  Suranga Lakmal      49619
# ...

# %%
dataset3
# Out:
#      RESULT     MARGIN  TOSS  BAT   OPPOSITION      GROUND `START_DATE`  \
# 0       won    85 runs  lost  1st      v India     Kolkata    03-Jan-13
# 1      lost    85 runs   won  2nd   v Pakistan     Kolkata    03-Jan-13
# 2      lost    10 runs  lost  2nd      v India       Delhi    06-Jan-13
# 3       won    10 runs   won  1st   v Pakistan       Delhi    06-Jan-13
# 4      lost   107 runs  lost  2nd  v Australia   Melbourne    11-Jan-13
# ...     ...        ...   ...  ...          ...         ...          ...
# 1317    won  3 wickets   won  2nd   v Pakistan  Nottingham    17-May-19
# 1318   aban          -     -    -   v Scotland   Edinburgh    18-May-19
# 1319      -          -   won  2nd    v Ireland     Belfast    19-May-19
# 1320      -          -  lost  2nd    v England       Leeds    19-May-19
# 1321      -          -   won  1st   v Pakistan       Leeds    19-May-19
#
#          MATCH_ID      COUNTRY  COUNTRY_ID
# 0      ODI # 3315     Pakistan           7
# ...

# %%
dataset3['RESULT']=dataset3['RESULT'].replace('-','0')
dataset3
# Out:
#      RESULT     MARGIN  TOSS  BAT   OPPOSITION      GROUND `START_DATE`  \
# 0       won    85 runs  lost  1st      v India     Kolkata    03-Jan-13
# 1      lost    85 runs   won  2nd   v Pakistan     Kolkata    03-Jan-13
# 2      lost    10 runs  lost  2nd      v India       Delhi    06-Jan-13
# 3       won    10 runs   won  1st   v Pakistan       Delhi    06-Jan-13
# 4      lost   107 runs  lost  2nd  v Australia   Melbourne    11-Jan-13
# ...     ...        ...   ...  ...          ...         ...          ...
# 1317    won  3 wickets   won  2nd   v Pakistan  Nottingham    17-May-19
# 1318   aban          -     -    -   v Scotland   Edinburgh    18-May-19
# 1319      0          -   won  2nd    v Ireland     Belfast    19-May-19
# 1320      0          -  lost  2nd    v England       Leeds    19-May-19
# 1321      0          -   won  1st   v Pakistan       Leeds    19-May-19
#
#          MATCH_ID      COUNTRY  COUNTRY_ID
# 0      ODI # 3315     Pakistan           7
# ...

# %%
dataset3['MARGIN']=dataset3['MARGIN'].replace('-','0')
dataset3
# Out:
#      RESULT     MARGIN  TOSS  BAT   OPPOSITION      GROUND `START_DATE`  \
# 0       won    85 runs  lost  1st      v India     Kolkata    03-Jan-13
# 1      lost    85 runs   won  2nd   v Pakistan     Kolkata    03-Jan-13
# 2      lost    10 runs  lost  2nd      v India       Delhi    06-Jan-13
# 3       won    10 runs   won  1st   v Pakistan       Delhi    06-Jan-13
# 4      lost   107 runs  lost  2nd  v Australia   Melbourne    11-Jan-13
# ...     ...        ...   ...  ...          ...         ...          ...
# 1317    won  3 wickets   won  2nd   v Pakistan  Nottingham    17-May-19
# 1318   aban          0     -    -   v Scotland   Edinburgh    18-May-19
# 1319      0          0   won  2nd    v Ireland     Belfast    19-May-19
# 1320      0          0  lost  2nd    v England       Leeds    19-May-19
# 1321      0          0   won  1st   v Pakistan       Leeds    19-May-19
#
#          MATCH_ID      COUNTRY  COUNTRY_ID
# 0      ODI # 3315     Pakistan           7
# ...

# %%
dataset3['TOSS']=dataset3['TOSS'].replace('-','0')
dataset3
# Out:
#      RESULT     MARGIN  TOSS  BAT   OPPOSITION      GROUND `START_DATE`  \
# 0       won    85 runs  lost  1st      v India     Kolkata    03-Jan-13
# 1      lost    85 runs   won  2nd   v Pakistan     Kolkata    03-Jan-13
# 2      lost    10 runs  lost  2nd      v India       Delhi    06-Jan-13
# 3       won    10 runs   won  1st   v Pakistan       Delhi    06-Jan-13
# 4      lost   107 runs  lost  2nd  v Australia   Melbourne    11-Jan-13
# ...     ...        ...   ...  ...          ...         ...          ...
# 1317    won  3 wickets   won  2nd   v Pakistan  Nottingham    17-May-19
# 1318   aban          0     0    -   v Scotland   Edinburgh    18-May-19
# 1319      0          0   won  2nd    v Ireland     Belfast    19-May-19
# 1320      0          0  lost  2nd    v England       Leeds    19-May-19
# 1321      0          0   won  1st   v Pakistan       Leeds    19-May-19
#
#          MATCH_ID      COUNTRY  COUNTRY_ID
# 0      ODI # 3315     Pakistan           7
# ...

# %%
dataset3['BAT']=dataset3['BAT'].replace('-','0')
dataset3
# Out:
#      RESULT     MARGIN  TOSS  BAT   OPPOSITION      GROUND `START_DATE`  \
# 0       won    85 runs  lost  1st      v India     Kolkata    03-Jan-13
# 1      lost    85 runs   won  2nd   v Pakistan     Kolkata    03-Jan-13
# 2      lost    10 runs  lost  2nd      v India       Delhi    06-Jan-13
# 3       won    10 runs   won  1st   v Pakistan       Delhi    06-Jan-13
# 4      lost   107 runs  lost  2nd  v Australia   Melbourne    11-Jan-13
# ...     ...        ...   ...  ...          ...         ...          ...
# 1317    won  3 wickets   won  2nd   v Pakistan  Nottingham    17-May-19
# 1318   aban          0     0    0   v Scotland   Edinburgh    18-May-19
# 1319      0          0   won  2nd    v Ireland     Belfast    19-May-19
# 1320      0          0  lost  2nd    v England       Leeds    19-May-19
# 1321      0          0   won  1st   v Pakistan       Leeds    19-May-19
#
#          MATCH_ID      COUNTRY  COUNTRY_ID
# 0      ODI # 3315     Pakistan           7
# ...

# %%
dataset3['OPPOSITION']=dataset3['OPPOSITION'].str.split('v ').str[1]
dataset3
# Out:
#      RESULT     MARGIN  TOSS  BAT OPPOSITION      GROUND `START_DATE`  \
# 0       won    85 runs  lost  1st      India     Kolkata    03-Jan-13
# 1      lost    85 runs   won  2nd   Pakistan     Kolkata    03-Jan-13
# 2      lost    10 runs  lost  2nd      India       Delhi    06-Jan-13
# 3       won    10 runs   won  1st   Pakistan       Delhi    06-Jan-13
# 4      lost   107 runs  lost  2nd  Australia   Melbourne    11-Jan-13
# ...     ...        ...   ...  ...        ...         ...          ...
# 1317    won  3 wickets   won  2nd   Pakistan  Nottingham    17-May-19
# 1318   aban          0     0    0   Scotland   Edinburgh    18-May-19
# 1319      0          0   won  2nd    Ireland     Belfast    19-May-19
# 1320      0          0  lost  2nd    England       Leeds    19-May-19
# 1321      0          0   won  1st   Pakistan       Leeds    19-May-19
#
#          MATCH_ID      COUNTRY  COUNTRY_ID
# 0      ODI # 3315     Pakistan           7
# ...

# %%
dataset3['MATCH_ID']=dataset3['MATCH_ID'].str.split('ODI # ').str[1]
dataset3
# Out:
#      RESULT     MARGIN  TOSS  BAT OPPOSITION      GROUND `START_DATE`  \
# 0       won    85 runs  lost  1st      India     Kolkata    03-Jan-13
# 1      lost    85 runs   won  2nd   Pakistan     Kolkata    03-Jan-13
# 2      lost    10 runs  lost  2nd      India       Delhi    06-Jan-13
# 3       won    10 runs   won  1st   Pakistan       Delhi    06-Jan-13
# 4      lost   107 runs  lost  2nd  Australia   Melbourne    11-Jan-13
# ...     ...        ...   ...  ...        ...         ...          ...
# 1317    won  3 wickets   won  2nd   Pakistan  Nottingham    17-May-19
# 1318   aban          0     0    0   Scotland   Edinburgh    18-May-19
# 1319      0          0   won  2nd    Ireland     Belfast    19-May-19
# 1320      0          0  lost  2nd    England       Leeds    19-May-19
# 1321      0          0   won  1st   Pakistan       Leeds    19-May-19
#
#      MATCH_ID      COUNTRY  COUNTRY_ID
# 0        3315     Pakistan           7
# 1        3315        India           6
# ...

# %%
dataset3['`START_DATE`']=pd.to_datetime(dataset3['`START_DATE`'])
dataset3
# Out:
#      RESULT     MARGIN  TOSS  BAT OPPOSITION      GROUND `START_DATE`  \
# 0       won    85 runs  lost  1st      India     Kolkata   2013-01-03
# 1      lost    85 runs   won  2nd   Pakistan     Kolkata   2013-01-03
# 2      lost    10 runs  lost  2nd      India       Delhi   2013-01-06
# 3       won    10 runs   won  1st   Pakistan       Delhi   2013-01-06
# 4      lost   107 runs  lost  2nd  Australia   Melbourne   2013-01-11
# ...     ...        ...   ...  ...        ...         ...          ...
# 1317    won  3 wickets   won  2nd   Pakistan  Nottingham   2019-05-17
# 1318   aban          0     0    0   Scotland   Edinburgh   2019-05-18
# 1319      0          0   won  2nd    Ireland     Belfast   2019-05-19
# 1320      0          0  lost  2nd    England       Leeds   2019-05-19
# 1321      0          0   won  1st   Pakistan       Leeds   2019-05-19
#
#      MATCH_ID      COUNTRY  COUNTRY_ID
# 0        3315     Pakistan           7
# 1        3315        India           6
# ...

# %%
dataset3['MATCH_ID'].unique()
# Out:
# array(['3315', '3316', '3317', '3318', '3319', '3320', '3321', '3322',
#        '3323', '3324', '3325', '3326', '3327', '3328', '3329', '3330',
#        '3331', '3332', '3333', '3334', '3335', '3336', '3337', '3338',
#        '3339', '3340', '3341', '3342', '3343', '3346', '3347', '3348',
#        '3349', '3350', '3351', '3352', '3353', '3354', '3355', '3356',
#        '3356a', '3357', '3358', '3359', '3360', '3361', '3362', '3363',
#        '3364', '3365', '3366', '3367', '3368', '3369', '3370', '3371',
#        '3372', '3373', '3374', '3375', '3376', '3377', '3378', '3380',
#        '3382', '3383', '3385', '3387', '3388', '3389', '3390', '3391',
#        '3392', '3393', '3394', '3395', '3396', '3397', '3398', '3399',
#        '3400', '3401', '3402', '3403', '3404', '3406', '3408', '3409',
#        '3410', '3410a', '3412', '3414', '3415', '3416', '3417', '3418',
#        '3419', '3420', '3421', '3422', '3422a', '3423', '3424', '3425',
# ...

# %%
dataset3['MATCH_ID']=dataset3['MATCH_ID'].str.split('a').str[0]
dataset3
# Out:
#      RESULT     MARGIN  TOSS  BAT OPPOSITION      GROUND `START_DATE`  \
# 0       won    85 runs  lost  1st      India     Kolkata   2013-01-03
# 1      lost    85 runs   won  2nd   Pakistan     Kolkata   2013-01-03
# 2      lost    10 runs  lost  2nd      India       Delhi   2013-01-06
# 3       won    10 runs   won  1st   Pakistan       Delhi   2013-01-06
# 4      lost   107 runs  lost  2nd  Australia   Melbourne   2013-01-11
# ...     ...        ...   ...  ...        ...         ...          ...
# 1317    won  3 wickets   won  2nd   Pakistan  Nottingham   2019-05-17
# 1318   aban          0     0    0   Scotland   Edinburgh   2019-05-18
# 1319      0          0   won  2nd    Ireland     Belfast   2019-05-19
# 1320      0          0  lost  2nd    England       Leeds   2019-05-19
# 1321      0          0   won  1st   Pakistan       Leeds   2019-05-19
#
#      MATCH_ID      COUNTRY  COUNTRY_ID
# 0        3315     Pakistan           7
# 1        3315        India           6
# ...

# %%
dataset3['MATCH_ID'].unique()
# Out:
# array(['3315', '3316', '3317', '3318', '3319', '3320', '3321', '3322',
#        '3323', '3324', '3325', '3326', '3327', '3328', '3329', '3330',
#        '3331', '3332', '3333', '3334', '3335', '3336', '3337', '3338',
#        '3339', '3340', '3341', '3342', '3343', '3346', '3347', '3348',
#        '3349', '3350', '3351', '3352', '3353', '3354', '3355', '3356',
#        '3357', '3358', '3359', '3360', '3361', '3362', '3363', '3364',
#        '3365', '3366', '3367', '3368', '3369', '3370', '3371', '3372',
#        '3373', '3374', '3375', '3376', '3377', '3378', '3380', '3382',
#        '3383', '3385', '3387', '3388', '3389', '3390', '3391', '3392',
#        '3393', '3394', '3395', '3396', '3397', '3398', '3399', '3400',
#        '3401', '3402', '3403', '3404', '3406', '3408', '3409', '3410',
#        '3412', '3414', '3415', '3416', '3417', '3418', '3419', '3420',
#        '3421', '3422', '3423', '3424', '3425', '3426', '3427', '3428',
# ...

# %%
dataset1
# Out:
#        BAT1 RUNS  BF    SR `4S` `6S`  OPPOSITION     GROUND `START_DATE`  \
# 0       DNB    0   0     0    0    0       India     Nagpur   2009-12-18
# 1       DNB    0   0     0    0    0       India    Kolkata   2009-12-24
# 2       DNB    0   0     0    0    0       India      Delhi   2009-12-27
# 3       DNB    0   0     0    0    0  Bangladesh      Dhaka   2010-01-04
# 4       DNB    0   0     0    0    0       India      Dhaka   2010-01-05
# ...     ...  ...  ..   ...  ...  ...         ...        ...          ...
# 11144    46   46  61  75.4    6    1     Ireland   Dehradun   2019-02-28
# 11145     3    3   6    50    0    0     Ireland   Dehradun   2019-03-02
# 11146     1    1   8  12.5    0    0     Ireland   Dehradun   2019-03-08
# 11147   DNB    0   0     0    0    0    Scotland  Edinburgh   2019-05-10
# 11148  TDNB    0   0     0    0    0     Ireland    Belfast   2019-05-19
#
#       MATCH_ID         BATSMAN  PLAYER_ID
# 0         2933   Oshane Thomas      49619
# ...

# %%
dataset2
# Out:
#       OVERS MDNS RUNS WKTS   ECON   AVE  SR  OPPOSITION       GROUND  \
# 0         8    0   57    0   7.12     0   0       India       Nagpur
# 1        10    0   55    2    5.5  27.5  30       India      Kolkata
# 2         0    0    0    0      0     0   0       India        Delhi
# 3         9    1   63    2      7  31.5  27  Bangladesh        Dhaka
# 4         8    1   48    0      6     0   0       India        Dhaka
# ...     ...  ...  ...  ...    ...   ...  ..         ...          ...
# 11113     4    0   41    0  10.25     0   0       India  Dubai (DSC)
# 11114   7.2    0   20    2   2.72    10  22     Ireland     Dehradun
# 11115     0    0    0    0      0     0   0     Ireland     Dehradun
# 11116     6    0   21    1    3.5    21  36     Ireland     Dehradun
# 11117    10    0   72    3    7.2    24  20    Scotland    Edinburgh
#
#       `START_DATE` MATCH_ID          BOWLER  PLAYER_ID
# 0       2009-12-18     2933  Suranga Lakmal      49619
# ...

# %%
dataset3
# Out:
#      RESULT     MARGIN  TOSS  BAT OPPOSITION      GROUND `START_DATE`  \
# 0       won    85 runs  lost  1st      India     Kolkata   2013-01-03
# 1      lost    85 runs   won  2nd   Pakistan     Kolkata   2013-01-03
# 2      lost    10 runs  lost  2nd      India       Delhi   2013-01-06
# 3       won    10 runs   won  1st   Pakistan       Delhi   2013-01-06
# 4      lost   107 runs  lost  2nd  Australia   Melbourne   2013-01-11
# ...     ...        ...   ...  ...        ...         ...          ...
# 1317    won  3 wickets   won  2nd   Pakistan  Nottingham   2019-05-17
# 1318   aban          0     0    0   Scotland   Edinburgh   2019-05-18
# 1319      0          0   won  2nd    Ireland     Belfast   2019-05-19
# 1320      0          0  lost  2nd    England       Leeds   2019-05-19
# 1321      0          0   won  1st   Pakistan       Leeds   2019-05-19
#
#      MATCH_ID      COUNTRY  COUNTRY_ID
# 0        3315     Pakistan           7
# 1        3315        India           6
# ...

# %%
final_df_Batsman = pd.DataFrame(dataset1)
final_df_Batsman
# Out:
#        BAT1 RUNS  BF    SR `4S` `6S`  OPPOSITION     GROUND `START_DATE`  \
# 0       DNB    0   0     0    0    0       India     Nagpur   2009-12-18
# 1       DNB    0   0     0    0    0       India    Kolkata   2009-12-24
# 2       DNB    0   0     0    0    0       India      Delhi   2009-12-27
# 3       DNB    0   0     0    0    0  Bangladesh      Dhaka   2010-01-04
# 4       DNB    0   0     0    0    0       India      Dhaka   2010-01-05
# ...     ...  ...  ..   ...  ...  ...         ...        ...          ...
# 11144    46   46  61  75.4    6    1     Ireland   Dehradun   2019-02-28
# 11145     3    3   6    50    0    0     Ireland   Dehradun   2019-03-02
# 11146     1    1   8  12.5    0    0     Ireland   Dehradun   2019-03-08
# 11147   DNB    0   0     0    0    0    Scotland  Edinburgh   2019-05-10
# 11148  TDNB    0   0     0    0    0     Ireland    Belfast   2019-05-19
#
#       MATCH_ID         BATSMAN  PLAYER_ID
# 0         2933   Oshane Thomas      49619
# ...

# %%
final_df_Bowler = pd.DataFrame(dataset2)
final_df_Bowler
# Out:
#       OVERS MDNS RUNS WKTS   ECON   AVE  SR  OPPOSITION       GROUND  \
# 0         8    0   57    0   7.12     0   0       India       Nagpur
# 1        10    0   55    2    5.5  27.5  30       India      Kolkata
# 2         0    0    0    0      0     0   0       India        Delhi
# 3         9    1   63    2      7  31.5  27  Bangladesh        Dhaka
# 4         8    1   48    0      6     0   0       India        Dhaka
# ...     ...  ...  ...  ...    ...   ...  ..         ...          ...
# 11113     4    0   41    0  10.25     0   0       India  Dubai (DSC)
# 11114   7.2    0   20    2   2.72    10  22     Ireland     Dehradun
# 11115     0    0    0    0      0     0   0     Ireland     Dehradun
# 11116     6    0   21    1    3.5    21  36     Ireland     Dehradun
# 11117    10    0   72    3    7.2    24  20    Scotland    Edinburgh
#
#       `START_DATE` MATCH_ID          BOWLER  PLAYER_ID
# 0       2009-12-18     2933  Suranga Lakmal      49619
# ...

# %%
final_df_match = pd.DataFrame(dataset3)
final_df_match
# Out:
#      RESULT     MARGIN  TOSS  BAT OPPOSITION      GROUND `START_DATE`  \
# 0       won    85 runs  lost  1st      India     Kolkata   2013-01-03
# 1      lost    85 runs   won  2nd   Pakistan     Kolkata   2013-01-03
# 2      lost    10 runs  lost  2nd      India       Delhi   2013-01-06
# 3       won    10 runs   won  1st   Pakistan       Delhi   2013-01-06
# 4      lost   107 runs  lost  2nd  Australia   Melbourne   2013-01-11
# ...     ...        ...   ...  ...        ...         ...          ...
# 1317    won  3 wickets   won  2nd   Pakistan  Nottingham   2019-05-17
# 1318   aban          0     0    0   Scotland   Edinburgh   2019-05-18
# 1319      0          0   won  2nd    Ireland     Belfast   2019-05-19
# 1320      0          0  lost  2nd    England       Leeds   2019-05-19
# 1321      0          0   won  1st   Pakistan       Leeds   2019-05-19
#
#      MATCH_ID      COUNTRY  COUNTRY_ID
# 0        3315     Pakistan           7
# 1        3315        India           6
# ...

# %%
final_df_Batsman.to_csv(r'E:\Cricket Data Analysis\export_batsman.csv', index=False, header=True)
final_df_Bowler.to_csv(r'E:\Cricket Data Analysis\export_bowler.csv', index=False, header=True)
final_df_match.to_csv(r'E:\Cricket Data Analysis\export_match.csv', index=False, header=True)
